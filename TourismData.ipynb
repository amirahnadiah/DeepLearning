# %% [markdown]
# <a href="https://colab.research.google.com/github/amirahnadiah/DeepLearning/blob/main/TourismData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_excel('API_ST.INT.ARVL_DS2_en_excel_v2_3011737.xls')

# %%
df=data.iloc[2:]

# %%
df.rename(columns=df.iloc[0], inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
dfnew = df.iloc[1:]

# %%
dfnew = dfnew.drop(['Indicator Name', 'Indicator Code'], axis = 1)

# %%
dfnew = dfnew.reset_index()
dfnew
# Out:
#      level_0  index  ...        2019.0 2020.0
# 0          0      3  ...  1.951000e+06    NaN
# 1          1      4  ...  3.982670e+07    NaN
# 2          2      5  ...           NaN    NaN
# 3          3      6  ...           NaN    NaN
# 4          4      7  ...  2.180000e+05    NaN
# ..       ...    ...  ...           ...    ...
# 261      261    264  ...           NaN    NaN
# 262      262    265  ...           NaN    NaN
# 263      263    266  ...  1.479700e+07    NaN
# 264      264    267  ...  1.266000e+06    NaN
# 265      265    268  ...  2.294000e+06    NaN
#
# [266 rows x 30 columns]

# %%
coloums_remove = [float(col) for col in range (1960, 1995)]

# %%
coloums_remove

# %%
dfnew = dfnew.drop (coloums_remove, axis =1 )

# %%
dfnew

# %%
dfnew2 = dfnew.fillna(dfnew.mean())

# %%
dfnew2.head(10)
# Out:
#    level_0  index  ...        2019.0 2020.0
# 0        0      3  ...  1.951000e+06    NaN
# 1        1      4  ...  3.982670e+07    NaN
# 2        2      5  ...  9.003628e+07    NaN
# 3        3      6  ...  9.003628e+07    NaN
# 4        4      7  ...  2.180000e+05    NaN
# 5        5      8  ...  6.406000e+06    NaN
# 6        6      9  ...  8.235000e+06    NaN
# 7        7     10  ...  1.160803e+08    NaN
# 8        8     11  ...  2.155300e+07    NaN
# 9        9     12  ...  7.399000e+06    NaN
#
# [10 rows x 30 columns]

# %%
dfnew.head(10)
# Out:
#    level_0  index  ...        2019.0 2020.0
# 0        0      3  ...  1.951000e+06    NaN
# 1        1      4  ...  3.982670e+07    NaN
# 2        2      5  ...           NaN    NaN
# 3        3      6  ...           NaN    NaN
# 4        4      7  ...  2.180000e+05    NaN
# 5        5      8  ...  6.406000e+06    NaN
# 6        6      9  ...  8.235000e+06    NaN
# 7        7     10  ...  1.160803e+08    NaN
# 8        8     11  ...  2.155300e+07    NaN
# 9        9     12  ...  7.399000e+06    NaN
#
# [10 rows x 30 columns]

# %%
dfnew2.to_csv('malaysian_tourism_data_1995-2019.csv')

# %%
dfnew2
# Out:
#      level_0  index  Country Name  ...        2018.0        2019.0  2020.0
# 0          0      3             0  ...  1.897000e+06  1.951000e+06     NaN
# 1          1      4             1  ...  4.118915e+07  3.982670e+07     NaN
# 2          2      5             2  ...  8.639792e+07  9.003628e+07     NaN
# 3          3      6             3  ...  8.639792e+07  9.003628e+07     NaN
# 4          4      7             4  ...  2.180000e+05  2.180000e+05     NaN
# ..       ...    ...           ...  ...           ...           ...     ...
# 261      261    264           261  ...  8.639792e+07  9.003628e+07     NaN
# 262      262    265           262  ...  8.639792e+07  9.003628e+07     NaN
# 263      263    266           263  ...  1.500400e+07  1.479700e+07     NaN
# 264      264    267           264  ...  1.072000e+06  1.266000e+06     NaN
# 265      265    268           265  ...  2.580000e+06  2.294000e+06     NaN
#
# [266 rows x 30 columns]

# %%
dfnew3 = dfnew2.drop(['level_0','index'], axis = 1)

# %%
dfnew3
# Out:
#                     Country Name Country Code  ...        2019.0  2020.0
# 0                          Aruba          ABW  ...  1.951000e+06     NaN
# 1    Africa Eastern and Southern          AFE  ...  3.982670e+07     NaN
# 2                    Afghanistan          AFG  ...  9.003628e+07     NaN
# 3     Africa Western and Central          AFW  ...  9.003628e+07     NaN
# 4                         Angola          AGO  ...  2.180000e+05     NaN
# ..                           ...          ...  ...           ...     ...
# 261                       Kosovo          XKX  ...  9.003628e+07     NaN
# 262                  Yemen, Rep.          YEM  ...  9.003628e+07     NaN
# 263                 South Africa          ZAF  ...  1.479700e+07     NaN
# 264                       Zambia          ZMB  ...  1.266000e+06     NaN
# 265                     Zimbabwe          ZWE  ...  2.294000e+06     NaN
#
# [266 rows x 28 columns]

# %%
high_1995 = dfnew3[1995.0].idxmax()

# %%
high_1995
# Out:
# 259

# %%
dfnew3.loc[[259]]
# Out:
#     Country Name Country Code        1995.0  ...        2018.0        2019.0  2020.0
# 259        World          WLD  1.024979e+09  ...  2.221459e+09  2.280131e+09     NaN
#
# [1 rows x 28 columns]

# %%
dfnew4 = dfnew3.drop([dfnew3.index[259]])

# %%
high_1995 = dfnew4[1995.0].idxmax()
high_1995
# Out:
# 181

# %%
dfnew4.loc[[181]]
# Out:
#      Country Name Country Code  ...        2019.0  2020.0
# 181  OECD members          OED  ...  1.342168e+09     NaN
#
# [1 rows x 28 columns]

# %%
dfnew4[1995.0].describe()
# Out:
# count    2.650000e+02
# mean     3.419869e+07
# std      9.618711e+07
# min      9.000000e+02
# 25%      3.700000e+05
# 50%      3.820369e+06
# 75%      3.792342e+07
# max      7.820643e+08
# Name: 1995.0, dtype: float64

# %%
dfnew4[2019.0].plot()
